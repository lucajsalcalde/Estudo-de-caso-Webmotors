# %%
#Instalando pacotes utilizados.
install.packages("tidyverse")

#Carregando pacotes.
library(tidyverse)

# %% [markdown]
# Na tabela abaixo se encontram os dados após a extração.

# %%
library(readr)
dados_site <- read_csv("../input/webmotorsdatabase/WebmotorsDados.csv")
#Visualizando database 
View(dados_site)

# %% [markdown]
#  Os dados originais apresentavam caracteres especiais nos nomes das cidades, devido ao uso de acentos.
#  Para corrigir o problema, foi necessário fazer a conversão de UTF8 para ASCII, utilizando VBA no Excel.
#
#   Código utilizado:
#
# Public Function fnConverterUTF8(ByVal Texto_para_converter As String)
#     Dim l As Long, sUTF8 As String
#     Dim iChar As Integer
#     Dim iChar2 As Integer
#
#     For l = 1 To Len(Texto_para_converter)
#         iChar = Asc(Mid(Texto_para_converter, l, 1))
#         If iChar > 127 Then
#             If Not iChar And 32 Then
#             iChar2 = Asc(Mid(Texto_para_converter, l + 1, 1))
#             sUTF8 = sUTF8 & ChrW$(((31 And iChar) * 64 + (63 And iChar2)))
#             l = l + 1
#         Else
#             Dim iChar3 As Integer
#             iChar2 = Asc(Mid(Texto_para_converter, l + 1, 1))
#             iChar3 = Asc(Mid(Texto_para_converter, l + 2, 1))
#             sUTF8 = sUTF8 & ChrW$(((iChar And 15) * 16 * 256) + ((iChar2 And 63) * 64) + (iChar3 And 63))
#             l = l + 2
#         End If
#             Else
#             sUTF8 = sUTF8 & Chr$(iChar)
#         End If
#     Next l
#     fnConverterUTF8 = sUTF8
# End Function
#
# **Além do Excel, utilizei o Power BI para a normalização dos dados.
#
# A tabela abaixo representa os dados prontos para a análise.**

# %%
library(readr)
dados_tratados <- read_csv("../input/dadostratados/DadosTratadosPBI.csv")
#Visualizando database 
View(dados_tratados)
